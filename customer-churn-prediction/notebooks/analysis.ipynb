# %% [markdown]
# # Telco Customer Churn Prediction - Comprehensive Analysis
#
# This Jupyter Notebook covers the end-to-end implementation of the Customer Churn Prediction project, including Supabase connection, Data Fetching, Exploratory Data Analysis (EDA), Feature Engineering, Data Preprocessing, Machine Learning Modeling, and Dashboard Visualization.

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv

# Ensure the src directory is accessible for custom modules
sys.path.append(os.path.abspath('../src'))

# Set plotting style
sns.set_theme(style='whitegrid')
load_dotenv('../.env')

# %% [markdown]
# ## 1. Data Fetching & Merging
# We fetch customer records from our local storage or Supabase cloud tables and merge them on `customer_id`.

# %%
from database import fetch_all_data

df = fetch_all_data()
df.head()

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
# Let's review the summary statistics, data types, and check for missing values.

# %%
print(f"Dataset Shape: {df.shape}")
print("\nData Types:")
print(df.dtypes)
print("\nMissing Values:")
print(df.isnull().sum())

# %% [markdown]
# ### Churn Distribution

# %%
plt.figure(figsize=(6, 5))
sns.countplot(data=df, x='churned', palette=['#4C72B0', '#C44E52'])
plt.title('Churned vs Retained Customers')
plt.show()

# %% [markdown]
# ## 3. Data Preprocessing
# We handle missing values, encode categorical variables, scale numerical features, and drop leaky variables.

# %%
from preprocessing import preprocess_data

X_train, X_test, y_train, y_test = preprocess_data()
X_train.head()

# %% [markdown]
# ## 4. Machine Learning Modeling
# We train and compare Logistic Regression and Decision Tree models.

# %%
from model import train_and_evaluate_models, generate_final_dashboard

results = train_and_evaluate_models()

# %% [markdown]
# ## 5. Final Business Dashboard
# Generating the comprehensive business presentation figure.

# %%
if results:
    generate_final_dashboard(results)
